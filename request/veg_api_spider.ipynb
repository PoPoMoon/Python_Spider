# %%
import requests
from time import sleep
# api 說明 
# StartDate=110.04.08 起始時間
# EndDate=110.04.08   結束時間 ；時間都沒給->從(當天)今天起起算1000筆資料
# CropCode=22         作物代號 
# =N05 沒有名稱直接=   作物品號 ；品號跟代號最好一起使用
# Crop='小白菜'        作物名稱
# Market=台北一       市場名稱

def main():
     
# 只有start會出現第N天及第N+1天，只有end會有第n天及第n-1天

    count=111
    month=['01','02','03','04','05','06','07','08','09','10','11','12']
    for i in range(1):
        count-=1
        for month_index in range(0,3):
            print('月的部分',month[month_index])
            start=f'{count}.{month[month_index]}.01'
            end=f'{count}.{month[month_index]}.31'
            
            farmsp=Farming_spider()
            farmsp.set_Start_Date(start)
            farmsp.set_End_Date(end)
    #         farmsp.set_Crop(crop='菠菜')
    #         farmsp.set_Crop_code(crop_code='LH3')
    #         LA1 = 高麗菜
            #     farmsp.set_Market(market='台北一')

#             print('交易日期','種類代碼','作物代號','作物名稱','市場代號','市場名稱','上價','上價','下價','平均價','交易量')
            data=farmsp.put_html_api()
            write_count=1
            while len(data)==1000:
                print(write_count)
                farmsp.url_skip_count()

                if write_count == 10:
#                     farmsp.go_write()
                    write_count=0

                data=farmsp.put_html_api()
                write_count+=1   

            if len(data)<1000:
                print('last的',end='')
#                 farmsp.go_write()
            print(farmsp.skip_count)
        
class Farming_spider():
    def __init__(self):
#         self.base_url='https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip=5000&StartDate=110.04.10'
        self.base_url='https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip='
        self.skip_count=0
        self.path=''
        self.s=''
        
        
    def put_html_api(self,crop=''):
#         url='https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip=5000&StartDate=110.04.10'
        url=f'{self.base_url}{self.skip_count}{self.path}'
        print(url)
        
        re=requests.get(url)
        data=re.json()
        s=''
        for i in data:
            if i==data[-1]:
                self.s+=i["交易日期"]+','+i["種類代碼"]+','+i["作物代號"]+','+i["作物名稱"]+','+i["市場代號"]+','+i["市場名稱"]+','+str(i["上價"])+','+str(i["中價"])+','+str(i["下價"])+','+str(i["平均價"])+','+str(i["交易量"])+'\n'
            else:
                self.s+=i["交易日期"]+','+i["種類代碼"]+','+i["作物代號"]+','+i["作物名稱"]+','+i["市場代號"]+','+i["市場名稱"]+','+str(i["上價"])+','+str(i["中價"])+','+str(i["下價"])+','+str(i["平均價"])+','+str(i["交易量"])+'\n'
            
#             info={
#             "交易日期":i["交易日期"],
#             "種類代碼":i["種類代碼"],
#             "作物代號":i["作物代號"],
#             "作物名稱":i["作物名稱"],
#             "市場代號":i["市場代號"],
#             "市場名稱":i["市場名稱"],
#             "上價":i["上價"],
#             "中價":i["中價"],
#             "下價":i["下價"],
#             "平均價":i["平均價"],
#             "交易量":i["交易量"]
#             }            

#         self.go_write(s)      #暫時關閉
        
        return data
    
    def url_skip_count(self):
        self.skip_count+=1000
        
    def set_Start_Date(self,start):
        self.path=f'{self.path}&StartDate={start}'
        
    def set_End_Date(self,end):
        self.path=f'{self.path}&EndDate={end}'   
    
    def set_Crop(self,crop):
        self.path=f'{self.path}&Crop={crop}'    
    
    def set_Crop_code(self,crop_code):
        self.path=f'{self.path}&CropCode={crop_code}' 
    
    def set_Market(self,market):
        self.path=f'{self.path}&Market={market}'
        
    def go_write(self):
        with open('D:/Download/Farm/all.csv','a',encoding='utf-8') as f:
            f.write(self.s)
        self.s=''
        print('寫入中')
        sleep(1)

if __name__=='__main__':
    main()
# Out:
# 月的部分 01
# https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip=0&StartDate=110.01.01&EndDate=110.01.31
# 1
# https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip=1000&StartDate=110.01.01&EndDate=110.01.31
# 2
# https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip=2000&StartDate=110.01.01&EndDate=110.01.31
# 3
# https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip=3000&StartDate=110.01.01&EndDate=110.01.31
# 4
# https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip=4000&StartDate=110.01.01&EndDate=110.01.31
# 5
# https://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx?$top=1000&$skip=5000&StartDate=110.01.01&EndDate=110.01.31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-8454142b7c1b> in <module>
# ...
